# %%
from workflow.graph import SupportAgentGraph

# %%
graph = SupportAgentGraph()

graph = graph.app
# Out:
# 2025-07-23 11:10:04,637 - sentence_transformers.SentenceTransformer - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2025-07-23 11:10:09,905 - workflow.graph - INFO - Support agent graph compiled successfully

# %%
from IPython.display import Image, display

# Render and display PNG diagram inline
# Default uses Mermaid.ink API under the hood
png_bytes = graph.get_graph().draw_mermaid_png()
display(Image(data=png_bytes))
